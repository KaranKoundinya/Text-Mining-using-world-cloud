# %% [markdown]
# Task 3: Using the wine.csv file available on the Moodle page and implementing a text mining technique, identify
# the top 5 MOST USED WORDS for each wine described.
# Represent your findings in Word Cloud Illustration for each wine likethe following example. The size of the
# words gets bigger as they becomemore frequently used.
#
#
# Solution: To tackle this question we have taken the apparoach of dividing the dataset on the basis of varieties of wines, i.e there are 41 different varieties of wine in the dataset, so we have created a dataset for each variety of wine with it's subsequent datapoints, So 41 datasets were uploaded to google colab to complete this task
# We have appended a screengrab of the 41 datasets uploaded to Google Colab
# We have also attached all the 41 files in the zipped folder on moodle for reference
# ![Screenshot 2022-12-15 215328.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
from os import path # The OS module in Python provides functions for interacting with the operating system for example os.path, etc.
#from PIL import Image #PIL is python imaging library
from wordcloud import WordCloud, STOPWORDS #ImageColorGenerator
import matplotlib.pyplot as plt
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# We have imported certain packages to be used in our code:
#
# With pandas it is a Python library used for working with data sets. It has functions for analyzing, cleaning, exploring, and manipulating data.
#
# Numpy is a Python library used for working with data sets. It has numerical functions for analyzing data
#
# from os import path : Python's OS module includes tools for dealing with the operating system, such as os.path, etc.
#
# from wordcloud import WordCloud :The size of each word in a word cloud, a data visualization technique for representing text data, indicates its frequency, so to by importing this library we can get the world cloud for our data
#
#  Matplotlib is a cross-platform package for data visualization and graphical plotting. Matplotlib will function like MATLAB thanks to the functions in pyplot. Each pyplot function transforms a figure in some form, like by producing a figure, a plotting section inside a figure, some lines inside a plotting area, identifying the plot, etc.
#
# from collections import Counter: Counter is a container in python that keeps track of how many times equivalent items are added, as well as Python Counter is a container that will hold the count of each element present in the container.
#
# import warnings: These are provided in situations in python where it indicates the user of the fact that there is a pre existing condition in which a warning  given doesn’t warrant raising an exception and terminating the program

# %%
df = pd.read_csv("/content/ALSACEWHITE BLAND.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas fucntion in python.
#
# Over here the Alsace white blend dataset is used to induct the Alsace white blend wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df
# Out:
#        country                                        description  \
# 370     France  The nose is like pear juice spilled onto warm ...
# 2734    France  Lifted notes of dried pear, dried chamomile fl...
# 2736    France  An incredibly pure and piercing note of lemon ...
# 3053    France  The lifted nose seems like an amalgam of chalk...
# 3303    France  Enticing aromas of freshly cut Cox Orange Pipp...
# 3309    France  Ripe notes of juicy yellow-pear waft from the ...
# 3946    France  Hints of sultana and cooked quince reach the n...
# 4248    France  Brilliant golden color promises richness. The ...
# 4465    France  The aroma recalls ripe, juicy pear peel. Likew...
# 4761    France  The nose needs air but as it wakes up, subtle ...
# 5113    France  Slightly muddled pear and earth flavors appear...
# 5363    France  Faint pear notes on the nose lead to a savory,...
# 5930    France  The nose is shy but subtly hints at citrus zes...
# ...

# %% [markdown]
# This is all the datapoints present in the Alsace white blend dataset

# %%
text = " ".join(description for description in df.description)
print ("The number of words are {}  in the description of Alsace white blend.".format(len(text)))
# Out:
# The number of words are 14630  in the description of Alsace white blend.

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration
#
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df1 = pd.read_csv("/content/Agiorgitiko.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas fucntion in python.
#
# Over here the Agiorgitiko dataset is used to induct the Agiorgitiko wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df1
# Out:
#        country                                        description  \
# 172     Greece  Aromas of leather, cherry and plum lead this b...
# 481     Greece  Aromas of leather, cherry and plum lead this b...
# 1331    Greece  Savory meat and vanilla on the nose lead into ...
# 5261    Greece  Forest fruit and pepper aromas lead into flavo...
# 5273    Greece  This is a great example of a variety Americans...
# ...        ...                                                ...
# 141806  Greece  If you could coat purple grapes in peanut dust...
# 142091  Greece  Cinnamon, spice and red berry aromas are touch...
# 142630  Greece  Fuller-bodied than many Agiorgitikos, this has...
# 142901  Greece  Red berry and cinnamon aromas start off this w...
# 143213  Greece  Rosy color hints at the lightness of this wine...
#
#                       designation  points  price     province      variety
# 172                           NaN      89   17.0        Nemea  Agiorgitiko
# ...

# %% [markdown]
# This is all the datapoints present in the Agiorgitiko dataset

# %%
text1 = " ".join(description for description in df1.description)
print ("The number of words are {}  in the description of Agiorgitiko.".format(len(text1)))
# Out:
# The number of words are 26543  in the description of Agiorgitiko.

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text1)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df2 = pd.read_csv("/content/Aglianico.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas fucntion in python.
#
# Over here the Aglianico dataset is used to induct the Aglianico dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df2
# Out:
#        country                                        description  \
# 459         US  Dried cranberry and currant flavors with raisi...
# 1194     Italy  Forest floor, leather, tilled soil, ripe berry...
# 1789     Italy  Undergrowth, truffle, black-skinned berry and ...
# 2049     Italy  Ripe plum, forest floor, truffle and dark spic...
# 2581     Italy  Spiced plum, vanilla, espresso and nutmeg arom...
# ...        ...                                                ...
# 146342   Italy  Deep, ripe and syrupy on the nose, with leathe...
# 146559   Italy  A spicy, sun-baked Aglianico that deals cherry...
# 147232   Italy  A young, chunky heavyweight is the only way to...
# 147593   Italy  Seems a bit late to just be making the market,...
# 147760   Italy  Bulky fruit, leather and some overt wood manif...
#
#                 designation  points  price        province    variety
# 459                     NaN      86   34.0      California  Aglianico
# ...

# %%
text2 = " ".join(description for description in df2.description)
print ("The number of words are {}  in the description of Aglianico.".format(len(text2)))
# Out:
# The number of words are 79223  in the description of Aglianico.

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text2)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df3 = pd.read_csv("/content/Aidani.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the Aidani dataset is used to induct the Aidani dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df3
# Out:
#       country                                        description  \
# 42479  Greece  Lemon, mineral and spice notes characterize th...
#
#           designation  points  price  province variety
# 42479  Estate Argyros      82     27  Cyclades  Aidani

# %% [markdown]
# This is all the datapoints present in the Aidani  dataset

# %%
text3 = " ".join(description for description in df3.description)
print ("The number of words are {}  in the description of Aidani.".format(len(text3)))
# Out:
# The number of words are 141  in the description of Aidani.

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text3)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df4 = pd.read_csv("/content/Airen.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the Airen dataset is used to induct the Airen dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df4
# Out:
#        country                                        description  \
# 14295    Spain  There's a reason Airén is used as a base grape...
# 50835    Spain  There's a reason Airén is used as a base grape...
# 56859    Spain  Airén is a big-crop white grape that is usuall...
# 90149    Spain  This is neutral on the nose except for a hint ...
# 96459    Spain  Airén is a big-crop white grape that is usuall...
# 105915   Spain  There's a reason Airén is used as a base grape...
#
#              designation  points  price       province variety
# 14295              Airén      80      9  Central Spain   Airen
# 50835              Airén      80      9  Central Spain   Airen
# 56859                NaN      83      8  Central Spain   Airen
# 90149   Diego de Almagro      82     10  Central Spain   Airen
# 96459                NaN      83      8  Central Spain   Airen
# 105915             Airén      80      9  Central Spain   Airen

# %% [markdown]
# This is all the datapoints present in the Airen dataset

# %%
text4 = " ".join(description for description in df4.description)
print ("The number of words are {}  in the description of Aidani.".format(len(text4)))
# Out:
# The number of words are 1493  in the description of Aidani.

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text4)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df5 = pd.read_csv("/content/Albana.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the Albana dataset is used to induct the Albana wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df5
# Out:
#          country                                        description  \
# 21174   Portugal  The leg here refers to the red-legged partridg...
# 22133      Italy  This is a beautiful and delicate dessert wine ...
# 22295      Italy  Colle del Re Passito is a gorgeous, smooth and...
# 33135      Italy  Albana di Romagna is a little-known white wine...
# 54065      Italy  This is one of those delicious amber-colored d...
# 54487      Italy  Scaccomatto (“checkmate” in Italian) is an ext...
# 54489      Italy  Honey, roasted chestnut, dried apricot, lychee...
# 55689      Italy  Arrocca is a deeply amber-colored wine with ge...
# 56496      Italy  There's a lot of fresh peach and honey here ba...
# 95007      Italy  The nice thing about this dessert wine is that...
# 96181      Italy  Romagna, in central Italy, has the soothing cl...
# 98479      Italy  The Albana varietal is usually made into desse...
# 99573      Italy  Packed with intensity and elegance, this opens...
# ...

# %% [markdown]
# This is all the datapoints present in the Albana dataset

# %%
text5 = " ".join(description for description in df5.description)
print ("The number of words are {}  in the description of Albana.".format(len(text5)))
# Out:
# The number of words are 4840  in the description of Albana.

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text5)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df6 = pd.read_csv("/content/Albaran.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the Albarin dataset is used to induct the Albarin wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df6
# Out:
#       country                                        description  \
# 23601   Spain  Citrusy on the nose, with tangerine and passio...
#
#            designation  points  price        province  variety
# 23601  Elverite Blanco      84     15  Northern Spain  Albarín

# %% [markdown]
# This is all the datapoints present in the Albarin dataset

# %%
text6 = " ".join(description for description in df6.description)
print ("The number of words are {}  in the description of Albarin.".format(len(text6)))
# Out:
# The number of words are 163  in the description of Albarin.

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text6)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df7 = pd.read_csv("/content/Albariato.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the Albarino dataset is used to induct the Alsace white blend wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on

# %%
df7
# Out:
#        country                                        description  \
# 144         US  Clean, sharp and zesty fruit blossom aromas me...
# 147      Spain  Aromas of white flowers, stone fruits and lees...
# 333      Spain  Lightly leesy aromas of vanilla cookie are off...
# 376         US  Not such a rarity these days, Albariño is turn...
# 395      Spain  Apple, lime and mineral aromas lend freshness ...
# ...        ...                                                ...
# 147645   Spain  Starts with fruit cocktail aromas, which are b...
# 147819   Spain  Tilts the scale on the heavy side. The nose is...
# 147837   Spain  Hard and waxy on the nose, with little to no a...
# 148026   Spain  Brass colored, with aromas of apple cider and ...
# 148031   Spain  Mealy on the nose, with corn and pear syrup ma...
#
#                   designation  points  price    province   variety
# 144           Jespersen Ranch      90   24.0  California  Albariño
# ...

# %% [markdown]
# This is all the datapoints present in the Albarino dataset

# %%
text7 = " ".join(description for description in df7.description)
print ("The number of words are {}  in the description of Albariño.".format(len(text7)))
# Out:
# The number of words are 138255  in the description of Albariño.

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text7)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df8 = pd.read_csv("/content/Albaroisa.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the Albarossa dataset is used to induct the Albarossa wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df8
# Out:
#       country                                        description designation  \
# 42829   Italy  If you've never heard of the Albarossa variety...     MonTald
#
#        points  price  province    variety
# 42829      88     40  Piedmont  Albarossa

# %% [markdown]
# This is all the datapoints present in the Albarasso dataset

# %%
text8 = " ".join(description for description in df8.description)
print ("The number of words are {}  in the description of Albarossa.".format(len(text8)))
# Out:
# The number of words are 274  in the description of Albarossa.

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text8)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df9 = pd.read_csv("/content/Alfrocheiro.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the  Alfrocheiro dataset is used to induct the Alfrocheiro wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df9
# Out:
#          country                                        description  \
# 1567    Portugal  The rich, fruity core of this 100% Alfrocheiro...
# 8322    Portugal  Normally found in the Dão region further north...
# 19406   Portugal  The spice and juicy fruit give the wine its in...
# 24827   Portugal  Powerful, concentrated wine, whose tannins fol...
# 32251   Portugal  More commonly found in the Dão region to the n...
# 33866   Portugal  The spice and juicy fruit give the wine its in...
# 44747   Portugal  Powerful, concentrated wine, whose tannins fol...
# 58344   Portugal  Normally grown in the Dão region, this grape n...
# 65054   Portugal  There's plenty going on here, from the sweet t...
# 76337   Portugal  Powerful, concentrated wine, whose tannins fol...
# 77966   Portugal  The spice and juicy fruit give the wine its in...
# 81301   Portugal  More commonly found in the Dão region to the n...
# 104648  Portugal  This wood-aged selection is soft and opulently...
# ...

# %% [markdown]
# This is all the datapoints present in the Alfrocheiro dataset

# %%
text9 = " ".join(description for description in df9.description)
print ("The number of words are {}  in the description of Alfrocheiro.".format(len(text9)))
# Out:
# The number of words are 4086  in the description of Alfrocheiro.

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text9)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df10 = pd.read_csv("/content/Alicante Bouschet.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the  Alicante Bouschet dataset is used to induct the Alicante Bouschet wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df10
# Out:
#           country                                        description  \
# 335      Portugal  The top wine in the Rocim range is produced fr...
# 995      Portugal  This is a dry sparkling wine with tannins, spi...
# 1760           US  The fact that this variety is still in the gro...
# 2991     Portugal  The red juiced Alicante Bouschet has produced ...
# 3827           US  This high-alcohol, full-bodied wine made from ...
# 5238     Portugal  An unusual bottling of 100% Alicante Bouschet,...
# 12937    Portugal  Dedicated to the producer's father, this 100% ...
# 19087    Portugal  A fine example of this sometimes tricky grape,...
# 20608    Portugal  Hugely black in color, a big-hearted wine that...
# 24774    Portugal  Almost black in color, this is a concentrated ...
# 28115    Portugal  The top wine in the Rocim range is produced fr...
# 30561    Portugal  The red juiced Alicante Bouschet has produced ...
# 31923    Portugal  Wines at 15.5% alcohol suggest too much of eve...
# ...

# %% [markdown]
# This is all the datapoints present in the Alicante Bouschet dataset

# %%
text10 = " ".join(description for description in df10.description)
print ("The number of words are {}  in the description of Alicante Bouschet.".format(len(text10)))
# Out:
# The number of words are 9395  in the description of Alicante Bouschet.

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text10)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df11 = pd.read_csv("/content/Alicante.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the  Alicante is used to induct the Alicante wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df11
# Out:
#        country                                        description  \
# 25446    Italy  Alicante imparts bright berry notes and sharp ...
# 35047    Italy  Alicante is making huge inroads in Tuscany. In...
# 40738    Italy  Based on Alicante, this wine shows bright acid...
# 41182    Italy  Alicante is a variant of Grenache (used widely...
# 47766    Italy  Alicante imparts bright berry notes and sharp ...
# 79326    Italy  Alicante imparts bright berry notes and sharp ...
# 84007    Italy  Alicante is making huge inroads in Tuscany. In...
# 98477    Italy  Notes of dried eucalyptus leaf, sage, savory s...
# 99032    Italy  Velvety aromas of ripe fruit, dried herb and c...
# 125676   Italy  Alicante imparts bright berry notes and sharp ...
#
#            designation  points  price province   variety
# 25446   Poggio al Tufo      87     24  Tuscany  Alicante
# 35047      Querciolaia      89     27  Tuscany  Alicante
# 40738      Acquagiusta      86     15  Tuscany  Alicante
# ...

# %% [markdown]
# This is all the datapoints present in the Alicante dataset

# %%
text11 = " ".join(description for description in df11.description)
print ("The number of words are {}  in the description of Alicante .".format(len(text11)))
# Out:
# The number of words are 2168  in the description of Alicante .

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text11)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df12 = pd.read_csv("/content/Aligota.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the  Aligote dataset is used to induct the Aligote wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df12
# Out:
#        country                                        description  \
# 1597        US  Hailing from 1970s plantings, this wine is dir...
# 10057   France  This fruity, ready-to-drink wine is crisp and ...
# 10449       US  This wine is a little short and abupt on the f...
# 22927   France  From one of the Leflaive family vineyards clos...
# 25127       US  A juicy wine, with plenty of ripe fruit border...
# 26169       US  Tastes like an inferior Chardonnay, with overo...
# 36714   France  Crisp, creamy wine, with attractive juicy appl...
# 37147   France  This fruity, ready-to-drink wine is crisp and ...
# 37580       US  This unique wine, made in California by Jed St...
# 40072   France  A crisp, almost herbaceous wine, this is refre...
# 51279       US  Tastes like an inferior Chardonnay, with overo...
# 63501   France  A crisp nose of stone, lemon and grass opens t...
# 67264   France  A lively, impressively fresh Aligoté, packed w...
# ...

# %% [markdown]
# This is all the datapoints present in the Aligote dataset

# %%
text12 = " ".join(description for description in df12.description)
print ("The number of words are {}  in the description of Aligoté .".format(len(text12)))
# Out:
# The number of words are 5057  in the description of Aligoté .

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text12)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df13 = pd.read_csv("/content/Altesse.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the  Altesse dataset is used to induct the Altesse wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df13
# Out:
#       country                                        description  designation  \
# 75347  France  This very lemony wine is crisp and cool from t...          NaN
#
#        points  price      province  variety
# 75347      89     18  France Other  Altesse

# %% [markdown]
# This is all the datapoints present in the Altesse dataset

# %%
text13 = " ".join(description for description in df13.description)
print ("The number of words are {}  in the description of Altesse .".format(len(text13)))
# Out:
# The number of words are 209  in the description of Altesse .

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text13)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df14 = pd.read_csv("/content/Alvarelheo.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the  Alvarelhão dataset is used to induct the Alvarelhão wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df14
# Out:
#        country                                        description  \
# 61962       US  This is a robust, rustic wine, rich in dark be...
# 116982      US  This is a robust, rustic wine, rich in dark be...
#
#                  designation  points  price    province     variety
# 61962   Silvaspoons Vineyard      84     18  California  Alvarelhão
# 116982  Silvaspoons Vineyard      84     18  California  Alvarelhão

# %% [markdown]
# This is all the datapoints present in the Alvarelhao dataset

# %%
text14 = " ".join(description for description in df14.description)
print ("The number of words are {}  in the description of Alvarelhão .".format(len(text14)))
# Out:
# The number of words are 299  in the description of Alvarelhão .

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text14)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df15 = pd.read_csv("/content/This is all the datapoints present in the Alsace white blend dataset.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the Alvarinho Chardonnay dataset is used to induct the Alvarinho Chardonnay wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on

# %%
df15
# Out:
#         country                                        description  \
# 4822   Portugal  Both herbal and tropical in character, this wi...
# 46647  Portugal  The Chardonnay and Alvarinho complement each o...
# 72111  Portugal  Two complementary grapes produce this ripe win...
#
#       designation  points  price province               variety
# 4822      Premium      88    NaN     Tejo  Alvarinho-Chardonnay
# 46647         DFJ      87   11.0   Lisboa  Alvarinho-Chardonnay
# 72111  Point West      87    9.0   Lisboa  Alvarinho-Chardonnay

# %% [markdown]
# This is all the datapoints present in the Alvarinho-Chardonnay dataset

# %%
text15 = " ".join(description for description in df15.description)
print ("The number of words are {}  in the description of Alvarinho-Chardonnay .".format(len(text15)))
# Out:
# The number of words are 719  in the description of Alvarinho-Chardonnay .

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text15)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df16 = pd.read_csv("/content/Alvarinho.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the  Alvarinho dataset is used to induct the Alvarinho wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df16
# Out:
#          country                                        description  \
# 277     Portugal  Pure Alvarinho from the Monção region, it's ri...
# 1542    Portugal  This pleasant, fruity wine has lemon-lime cris...
# 2923    Portugal  An elegant Alvarinho from the north of the Vin...
# 6621    Portugal  This is a delicious refreshing wine with great...
# 6819    Portugal  This is a delicious refreshing wine with great...
# ...          ...                                                ...
# 136996  Portugal  This is a 100% Alvarinho, perfumed with hints ...
# 137555  Portugal  This small estate bottling is an attractive, f...
# 140222  Portugal  As it should be from the year and the grape, t...
# 141162  Portugal  Although it lacks the creamy crispness of Alav...
# 143575  Portugal  Pricey for a Vinho Verde, but one of the best ...
#
#               designation  points  price     province    variety
# 277     Portal do Fidalgo      92   35.0  Vinho Verde  Alvarinho
# ...

# %% [markdown]
# This is all the datapoints present in the Alvarinho dataset

# %%
text16 = " ".join(description for description in df16.description)
print ("The number of words are {}  in the description of Alvarinho .".format(len(text16)))
# Out:
# The number of words are 16288  in the description of Alvarinho .

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text16)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df17 = pd.read_csv("/content/Angevine.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the  Angevine dataset is used to induct the Angevine wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df17
# Out:
#        country                                        description  \
# 63596       US  From the estate vineyard, this bone-dry white ...
# 115750      US  This has interesting spice in both the nose an...
# 130739      US  Folks seeking low alcohol wines should be snif...
# 144460      US  This has interesting spice in both the nose an...
# 147326      US  From the estate vineyard, this bone-dry white ...
#
#             designation  points  price    province   variety
# 63596         Madeleine      87     12  Washington  Angevine
# 115750  Estate Madeline      86     12  Washington  Angevine
# 130739              NaN      88     14  Washington  Angevine
# 144460  Estate Madeline      86     12  Washington  Angevine
# 147326        Madeleine      87     12  Washington  Angevine

# %% [markdown]
# This is all the datapoints present in the Angevine dataset

# %%
text17 = " ".join(description for description in df17.description)
print ("The number of words are {}  in the description of 	Angevine .".format(len(text17)))
# Out:
# The number of words are 1407  in the description of 	Angevine .

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text17)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df18 = pd.read_csv("/content/Anlaeo Vaz.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the  Antao Vaz dataset is used to induct the Antao Vaz wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df18
# Out:
#          country                                        description  \
# 4421    Portugal  With aromas of wood aging, this is a tropical ...
# 6622    Portugal  This is a rich, very rich wine that is packed ...
# 6820    Portugal  This is a rich, very rich wine that is packed ...
# 24712   Portugal  Soft-textured wine, with an edge of minerality...
# 34192   Portugal  This is a rich, very rich wine that is packed ...
# 34240   Portugal  This is a rich, very rich wine that is packed ...
# 38247   Portugal  Very rich, this is a smooth spicy wine, its fr...
# 40756   Portugal  This rich, spicy wine holds beautiful lemon fr...
# 44182   Portugal  Soft-textured wine, with an edge of minerality...
# 47307   Portugal  Bright and crisp, this fruity wine shows touch...
# 72386   Portugal  Pato Frio—cold duck—suggests this a summer pic...
# 82017   Portugal  Very rich, this is a smooth spicy wine, its fr...
# 85355   Portugal  Considering its richness and alcohol, this win...
# ...

# %% [markdown]
# This is all the datapoints present in the Antao Vaz dataset

# %%
text18 = " ".join(description for description in df18.description)
print ("The number of words are {}  in the description of Antão Vaz .".format(len(text18)))
# Out:
# The number of words are 3592  in the description of Antão Vaz .

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text18)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df19 = pd.read_csv("/content/Ansonica.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the  Ansonica dataset is used to induct the Ansonica wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df19
# Out:
#        country                                        description  \
# 82150    Italy  Chiaramonte is an easy, refreshing expression ...
# 117138   Italy  This single variety Ansonica is crisp and fres...
# 130968   Italy  This single variety Ansonica is crisp and fres...
# 137869   Italy  This is a crisp summer wine with more dimensio...
#
#            designation  points  price           province   variety
# 82150      Chiaramonte      87   18.0  Sicily & Sardinia  Ansonica
# 117138  Vigna di Gabri      89    NaN  Sicily & Sardinia  Ansonica
# 130968  Vigna di Gabri      89    NaN  Sicily & Sardinia  Ansonica
# 137869  Vigna di Gabri      87    NaN  Sicily & Sardinia  Ansonica

# %% [markdown]
# This is all the datapoints present in the Ansonica dataset

# %%
text19 = " ".join(description for description in df19.description)
print ("The number of words are {}  in the description of Ansonica .".format(len(text19)))
# Out:
# The number of words are 1054  in the description of Ansonica .

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text19)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df20 = pd.read_csv("/content/Apple.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the  Apple dataset is used to induct the Apple wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df20
# Out:
#        country                                        description  \
# 108089  Canada  A beautiful Quebec classic ice cider, with vib...
# 108342  Canada  With over 80 apples used to produce each bottl...
# 108356      US  A lovely drink from a winery in Massachusetts ...
# 120929  Canada  A beautiful Quebec classic ice cider, with vib...
# 121242  Canada  With over 80 apples used to produce each bottl...
# 121256      US  A lovely drink from a winery in Massachusetts ...
#
#                      designation  points  price       province variety
# 108089      Neige Apple Ice Wine      90     35   Canada Other   Apple
# 108342            Ice Apple Wine      89     33   Canada Other   Apple
# 108356  Apfel Eis Apple Ice Wine      89     25  Massachusetts   Apple
# 120929      Neige Apple Ice Wine      90     35   Canada Other   Apple
# 121242            Ice Apple Wine      89     33   Canada Other   Apple
# 121256  Apfel Eis Apple Ice Wine      89     25  Massachusetts   Apple

# %% [markdown]
# This is all the datapoints present in the Apple white blend dataset

# %%
text20 = " ".join(description for description in df20.description)
print ("The number of words are {}  in the description of Apple .".format(len(text20)))
# Out:
# The number of words are 2131  in the description of Apple .

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text20)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df21 = pd.read_csv("/content/Aragonas.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the  Aragones dataset is used to induct the Aragones wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on

# %%
df21
# Out:
#          country                                        description  \
# 345     Portugal  This is a rich, full-bodied wine that is ready...
# 3244    Portugal  Proudly boasting that there were no added sulp...
# 19993   Portugal  Smooth as Aragonês should be, here is a concen...
# 20473   Portugal  Rich and soft, very smooth, this Alentejo vers...
# 28125   Portugal  This is a rich, full-bodied wine that is ready...
# 30874   Portugal  Proudly boasting that there were no added sulp...
# 39067   Portugal  Aragonês, a k a Tempranillo and Tinta Roriz, i...
# 82927   Portugal  Aragonês, a k a Tempranillo and Tinta Roriz, i...
# 102952  Portugal  The local version of the Spanish Tempranillo, ...
# 103244  Portugal  A soft, but spicy wine made from the Portugues...
# 103534  Portugal  Big and dense, the tannins showing a dusty cha...
# 103830  Portugal  Smooth, wood-polished wine, packed with a ripe...
# 104783  Portugal  Dense tannins dominate this wine. The black cu...
# ...

# %% [markdown]
# This is all the datapoints present in the Aragones dataset

# %%
text21 = " ".join(description for description in df21.description)
print ("The number of words are {}  in the description of Aragonês.".format(len(text21)))
# Out:
# The number of words are 3678  in the description of Aragonês.

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text21)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df22 = pd.read_csv("/content/Aragonez.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the  Aragonez dataset is used to induct the Aragonez wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df22
# Out:
#          country                                        description  \
# 3170    Portugal  A bold, rich wine fringed with tannins, at a y...
# 29215   Portugal  Aragonez, aka Tempranillo, here produces a rip...
# 38159   Portugal  Aragonez, aka Tempranillo, is the Tinta Roriz ...
# 39901   Portugal  A ripe, smoky wood- and black fruit-driven win...
# 40451   Portugal  This is an herbal wine made without any use of...
# 48777   Portugal  Initially just juicy black currants, it shows ...
# 83761   Portugal  A ripe, smoky wood- and black fruit-driven win...
# 98733   Portugal  Fruity, juicy and packed with red berry fruit,...
# 101375  Portugal  This is a smooth, rounded wine, showing the el...
#
#                    designation  points  price    province   variety
# 3170                       NaN      90   24.0  Alentejano  Aragonez
# 29215                  Ciconia      85   10.0  Alentejano  Aragonez
# 38159                      NaN      90    NaN  Alentejano  Aragonez
# ...

# %% [markdown]
# This is all the datapoints present in the Aragonez dataset

# %%
text22 = " ".join(description for description in df22.description)
print ("The number of words are {}  in the description of Aragonez.".format(len(text22)))
# Out:
# The number of words are 1844  in the description of Aragonez.

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text22)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df23 = pd.read_csv("/content/Argaman.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the  Argaman dataset is used to induct the Argaman wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on

# %%
df23
# Out:
#       country                                        description  \
# 40725  Israel  This bold red made from Argaman—a cross betwee...
# 44895  Israel  Here's an interesting red that's like a ripe, ...
# 99795  Israel  Here's an interesting red that's like a ripe, ...
#
#                         designation  points  price province  variety
# 40725         Dovev Single Vineyard      86     38    Galil  Argaman
# 44895  Dovev Single Vineyard Kosher      88     36    Galil  Argaman
# 99795  Dovev Single Vineyard Kosher      88     36    Galil  Argaman

# %% [markdown]
# This is all the datapoints present in the Argaman dataset

# %%
text23 = " ".join(description for description in df23.description)
print ("The number of words are {}  in the description of Argaman.".format(len(text23)))
# Out:
# The number of words are 839  in the description of Argaman.

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text23)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df24 = pd.read_csv("/content/Arinto.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the  Arinto dataset is used to induct the Arinto wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df24
# Out:
#          country                                        description  \
# 1357    Portugal  Initially this wine is smooth and creamy textu...
# 1846    Portugal  This is a soft and crisp wine that shows attra...
# 2947    Portugal  This is a wine that shows a more serious side ...
# 3738    Portugal  A Portuguese classic, this fresh and fruity wi...
# 4956    Portugal  As its name implies, the wine comes from chalk...
# ...          ...                                                ...
# 134855  Portugal  Primarily Arinto, this distinctive, interestin...
# 134959  Portugal  Made from the Arinto grape, this wine has a li...
# 135755  Portugal  Pure Arinto, this wine brings lemon and pineap...
# 137901  Portugal  The brand Bucellas (with two “l”s) has been ma...
# 143739  Portugal  Lime and chalk dust aromas ease into flavors o...
#
#                                   designation  points  price     province  \
# 1357     Quinta do Encontro Encontro I Branco      91   40.0     Bairrada
# ...

# %% [markdown]
# This is all the datapoints present in the Arinto dataset

# %%
text24 = " ".join(description for description in df24.description)
print ("The number of words are {}  in the description of Arinto.".format(len(text24)))
# Out:
# The number of words are 14475  in the description of Arinto.

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text24)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df25 = pd.read_csv("/content/Arnies.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the  Arneis dataset is used to induct the Arneis wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df25
# Out:
#        country                                        description  \
# 3921     Italy  This bright Arneis boasts sensations of tart g...
# 16018    Italy  The Il Falchetto offers lovely aromas of fresh...
# 16595    Italy  The Ceretto was surprisingly evolved for a 200...
# 16598    Italy  The Ascheri is a light-colored wine with a lov...
# 16917    Italy  At first, the Damilano seemed fairly non-descr...
# ...        ...                                                ...
# 128356   Italy  Here's an extremely food-friendly white wine f...
# 129704   Italy  Bracing notes of quince are the opening act fo...
# 137248   Italy  The Il Falchetto offers lovely aromas of fresh...
# 145517   Italy  So pale that it's almost colorless, the Blangé...
# 147564      US  From this Italian variety comes a light, pleas...
#
#              designation  points  price    province variety
# 3921                 NaN      87   15.0    Piedmont  Arneis
# ...

# %% [markdown]
# This is all the datapoints present in the Arneis dataset

# %%
text25 = " ".join(description for description in df25.description)
print ("The number of words are {}  in the description of Arneis.".format(len(text25)))
# Out:
# The number of words are 15555  in the description of Arneis.

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text25)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df26 = pd.read_csv("/content/Asprinio.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the  Asprinio dataset is used to induct the Asprinio wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df26
# Out:
#       country                                        description  designation  \
# 81376   Italy  This is a unique wine that opens with aromas o...          NaN
#
#        points  price        province   variety
# 81376      83    NaN  Southern Italy  Asprinio

# %% [markdown]
# This is all the datapoints present in the Asprinio white blend dataset

# %%
text26 = " ".join(description for description in df26.description)
print ("The number of words are {}  in the description of Asprinio.".format(len(text26)))
# Out:
# The number of words are 228  in the description of Asprinio.

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text26)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df27 = pd.read_csv("/content/Assyritko.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the  Assyritko dataset is used to induct the Assyritko wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on

# %%
df27
# Out:
#       country                                        description  \
# 153    Greece  Bright aromas of citrus and tropical fruit giv...
# 559    Greece  Crisp acidity and a gorgeous, aromatic nose le...
# 811    Greece  Crisp acidity and a gorgeous, aromatic nose le...
# 1133      NaN  Delicate white flowers and a spin of lemon pee...
# 1417   Greece  Pineapple and lime peel start the nose of this...
# 7028   Greece  Soft white peach and citrus aromas are touched...
# 30386  Greece  The fuller bodied, layered Assyrtiko from nort...
# 33675  Greece  A fresh and fruity nose of lemon, white flower...
#
#                    designation  points  price   province    variety
# 153                        NaN      89     21  Santorini  Assyrtiko
# 559                        NaN      90     20  Santorini  Assyrtiko
# 811                        NaN      90     20  Santorini  Assyrtiko
# 1133                 Askitikos      90     17        NaN  Assyrtiko
# ...

# %% [markdown]
# This is all the datapoints present in the Assyrtiko dataset

# %%
text27 = " ".join(description for description in df27.description)
print ("The number of words are {}  in the description of Assyrtiko.".format(len(text27)))
# Out:
# The number of words are 1863  in the description of Assyrtiko.

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text27)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df28 = pd.read_csv("/content/Assyrtico.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the  Assyrtico dataset is used to induct the Assyrtico wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df28
# Out:
#        country                                        description  \
# 3588    Greece  Grapefruit, lemon and star anise aromas lead t...
# 3814    Greece  Grapefruit, lemon and star anise aromas lead t...
# 4452    Greece  White flowers and peach aromas start this full...
# 5260    Greece  The Kallisti offers exotic pineapple and tropi...
# 5834    Greece  Grapefruit and orange peel aromas are followed...
# ...        ...                                                ...
# 140601  Greece  Looks like liquid sunshine, and has a creamy t...
# 141495  Greece  The shy nose hints at plantain, caramel, peach...
# 142382  Greece  Mineral and citrus flavors zip through the mou...
# 142397  Greece  Butterscotch, baked apple and holiday spice ar...
# 143193  Greece  Made from 100% Assyrtico, this starts off with...
#
#              designation  points  price   province    variety
# 3588                 NaN      89     20  Santorini  Assyrtico
# ...

# %% [markdown]
# This is all the datapoints present in the Assyrtico dataset

# %%
text28 = " ".join(description for description in df28.description)
print ("The number of words are {}  in the description of Assyrtico.".format(len(text28)))
# Out:
# The number of words are 15989  in the description of Assyrtico.

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text28)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df29 = pd.read_csv("/content/Athiri.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the  Athiri dataset is used to induct the Athiri wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df29
# Out:
#        country                                        description  \
# 88797   Greece  Spice, citrus and minerals typify the nose and...
# 136497  Greece  Spice, citrus and minerals typify the nose and...
#
#             designation  points  price province variety
# 88797   Mountain Slopes      83     18   Greece  Athiri
# 136497  Mountain Slopes      83     18   Greece  Athiri

# %% [markdown]
# This is all the datapoints present in the Athiri dataset

# %%
text29 = " ".join(description for description in df29.description)
print ("The number of words are {}  in the description of Athiri.".format(len(text29)))
# Out:
# The number of words are 311  in the description of Athiri.

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text29)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df30 = pd.read_csv("/content/Austrian RedBland.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the  Austrian Red Blend dataset is used to induct the Austrian Red Blend wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df30
# Out:
#         country                                        description  \
# 3435    Austria  Cinnamon and pepper add interest to the ripe b...
# 5970    Austria  Ripe blackberry notes dominate this wine's nos...
# 10211   Austria  A straightforward red, with ripe cherry flavor...
# 13980   Austria  This is a rich success. It has concentration, ...
# 14817   Austria  A complex, concentrated wine. It shows richnes...
# ...         ...                                                ...
# 140898  Austria  Spicy aromas in this blend of Blaufränkisch an...
# 140900  Austria  There's pretty much every red variety in the P...
# 141191  Austria  A complex blend of Zweigelt, Blaufränkisch, St...
# 141527  Austria  Gerhard Markowitsch's house wine reveals his s...
# 141529  Austria  A warming, ripe wine, freshly juicy, but with ...
#
#                       designation  points  price             province  \
# 3435                     Beck Ink      91    NaN  Weinland Österreich
# ...

# %% [markdown]
# This is all the datapoints present in the Austrian Red Bland dataset

# %%
text30 = " ".join(description for description in df30.description)
print ("The number of words are {}  in the description of Austrian Red Blend.".format(len(text30)))
# Out:
# The number of words are 14796  in the description of Austrian Red Blend.

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text30)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df31 = pd.read_csv("/content/Austrian WhiteBland.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the  Austrian White Bland dataset is used to induct the Austrian White Bland wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df31
# Out:
#         country                                        description  \
# 11672   Austria  There is just a touch of wood in this rich and...
# 14967   Austria  This is an off-dry blend of Zierfandler, Rotgi...
# 16190   Austria  Perfumed and spicy, this has fine acidity and ...
# 16518   Austria  This is a complex, rounded wine. It's texture ...
# 17954   Austria  This is a ripe, full-in-the-mouth wine. The cr...
# 18364   Austria  Bright and attractively fruity, this has pear ...
# 22307   Austria  The Nussberg vineyard towering above the weste...
# 22410   Austria  Rich wine, a blend dominated by the rare Rotgi...
# 22970   Austria  A sophisticated wine that shows richness, crea...
# 23216   Austria  The typical field blend from Vienna, full and ...
# 23339   Austria  This field blend from the Nussdorf vineyard on...
# 26749   Austria  Showing apricot and honey flavors with a refre...
# 26794   Austria  With the heart-stopping acidity and intensity ...
# ...

# %% [markdown]
# This is all the datapoints present in the Austrian white blend dataset

# %%
text31 = " ".join(description for description in df31.description)
print ("The number of words are {}  in the description of Austrian white blend.".format(len(text31)))
# Out:
# The number of words are 10420  in the description of Austrian white blend.

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text31)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df32 = pd.read_csv("/content/Auxerois.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the  Auxerrois dataset is used to induct the Auxerrois wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df32
# Out:
#        country                                        description  \
# 1737    France  Lemon freshness encounters some honeyed richne...
# 2010    France  The softest hint of apricot can be discerned o...
# 2728    France  A touch of earth is bound up with the ripe, ju...
# 3304    France  Full-fruited, expressive notes of ripe pear sh...
# 4933   Germany  Auxerrois, a grape variety rarely seen in the ...
# 11246   France  A fresh nose suggests both green and yellow pe...
# 11544       US  Very little Auxerrois is grown in Oregon, and ...
# 13791       US  Add Raptor Ridge to the slender ranks of Orego...
# 19155       US  Tart and spicy, the latest release of Adelshei...
# 28569       US  This is another fine vintage for this rare win...
# 39458   France  Although in the Alsace grape hierarchy, Auxerr...
# 46089       US  Solid as ever, this lip-smackingly refreshing ...
# 74217       US  Super fragrant, with lush scents of citrus, ap...
# ...

# %% [markdown]
# This is all the datapoints present in the Auxerrois dataset

# %%
text32 = " ".join(description for description in df32.description)
print ("The number of words are {}  in the description of Auxerrois.".format(len(text32)))
# Out:
# The number of words are 4295  in the description of Auxerrois.

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text32)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df33 = pd.read_csv("/content/Avesso.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the  Avesso dataset is used to induct the Avesso wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df33
# Out:
#         country                                        description  \
# 75349  Portugal  A full-bodied wine, ripely fruity while preser...
# 79119  Portugal  There is a definite spritz to this ripe and cr...
# 96092  Portugal  Avesso, a rare varietal in the Vinho Verde reg...
#
#       designation  points  price     province variety
# 75349         NaN      89     15  Vinho Verde  Avesso
# 79119      Avesso      89     13  Vinho Verde  Avesso
# 96092         NaN      88     16  Vinho Verde  Avesso

# %% [markdown]
# This is all the datapoints present in the Avesso dataset

# %%
text33 = " ".join(description for description in df33.description)
print ("The number of words are {}  in the description of Avesso.".format(len(text33)))
# Out:
# The number of words are 653  in the description of Avesso.

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text33)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df34 = pd.read_csv("/content/Azal.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the  Azal dataset is used to induct the Azal wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df34
# Out:
#         country                                        description  \
# 83917  Portugal  A wine with some density of flavor to go with ...
#
#       designation  points  price     province variety
# 83917        Azal      87     13  Vinho Verde    Azal

# %% [markdown]
# This is all the datapoints present in the Azal dataset

# %%
text34 = " ".join(description for description in df34.description)
print ("The number of words are {}  in the description of Azal.".format(len(text34)))
# Out:
# The number of words are 140  in the description of Azal.

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text34)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df35 = pd.read_csv("/content/Baco Noir.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the  Baco Noir dataset is used to induct the Baco Noir wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df35
# Out:
#       country                                        description  \
# 2211       US  Aromatic and drinking at its peak, this remain...
# 39983      US  There is a horsey, leathery scent as you first...
# 43233      US  While sweet and cheerful on the nose with scen...
# 43825      US  Delightful rose and violet perfume mingles wit...
# 44703      US  Unfiltered and unfined, this wine made from 60...
# 45857      US  Concentrated black fruit flavors are pleasant ...
# 46818      US  Scents of black coffee and ripe black fruit me...
# 50270      US  This rarely seen variety (a hybrid from a cros...
# 92123      US  There is a horsey, leathery scent as you first...
#
#                                          designation  points  price  province  \
# 2211                                             NaN      88     18    Oregon
# 39983                                            NaN      85     26    Oregon
# 43233                      Casscles Vineyard Reserve      87     20  New York
# ...

# %% [markdown]
# This is all the datapoints present in the Baco Noir dataset

# %%
text35 = " ".join(description for description in df35.description)
print ("The number of words are {}  in the description of Baco Noir.".format(len(text35)))
# Out:
# The number of words are 2242  in the description of Baco Noir.

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text35)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df36 = pd.read_csv("/content/Baga Touriga Nacional.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the  Baga Touriga Nacional dataset is used to induct the Baga Touriga Nacional dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df36
# Out:
#         country                                        description  \
# 13035  Portugal  Big, black colored wine that is firm and solid...
#
#        designation  points  price province                variety
# 13035          NaN      91     20   Beiras  Baga-Touriga Nacional

# %% [markdown]
# This is all the datapoints present in the Baga-Touriga Nacional dataset

# %%
text36 = " ".join(description for description in df36.description)
print ("The number of words are {}  in the description of Baga-Touriga Nacional.".format(len(text36)))
# Out:
# The number of words are 219  in the description of Baga-Touriga Nacional.

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text36)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df37 = pd.read_csv("/content/Baga.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the  Baga dataset is used to induct the Baga wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df37
# Out:
#          country                                        description  \
# 91      Portugal  The local Baga grape, better known for produci...
# 521     Portugal  This is a rich, full-bodied and wood-aged wine...
# 5229    Portugal  Baga, a grape unique to the Bairrada region, h...
# 5549    Portugal  Firm and dense, this is a fine example of the ...
# 6355    Portugal  After five years, the Baga is beginning to sof...
# 15168   Portugal  Luis Pato's Bairradas used to be the standouts...
# 20221   Portugal  A finely perfumed wine, its ripe fruits given ...
# 33925   Portugal  After five years, the Baga is beginning to sof...
# 36160   Portugal  A rich wine, full of dark plums, big and dusty...
# 36290   Portugal  Baga can be a shock to the palate because of i...
# 51529   Portugal  As the base for a sparkling wine, Baga doesn't...
# 65816   Portugal  Bairrada's difficult grape, the Baga, needs ti...
# 67479   Portugal  A juicy, Baga-dominated wine, all soft black f...
# ...

# %% [markdown]
# This is all the datapoints present in the Baga dataset

# %%
text37 = " ".join(description for description in df37.description)
print ("The number of words are {}  in the description of Baga.".format(len(text37)))
# Out:
# The number of words are 5591  in the description of Baga.

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text37)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df38 = pd.read_csv("/content/Barbera.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the  Barbera dataset is used to induct the Barbera wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df38
# Out:
#        country                                        description  \
# 132         US  Meaty, smoky aromas and good, high-amplitude f...
# 477         US  This dull, rustic wine offers earth and anise ...
# 640      Italy  Firm and full-bodied, this opens with aromas o...
# 651      Italy  Aromas of mature dark-skinned fruit, scorched ...
# 830         US  A winning combination of seductive, spicy arom...
# ...        ...                                                ...
# 148510      US  A good California Barbera, with medium weight,...
# 148819      US  Tough and gritty in acids and tannins, this wi...
# 148903      US  The wine has a very soft entry, with sweet, al...
# 150248      US  What a big, dark, rich wine this is. It's clas...
# 150734   Italy  Brisk acidity and a lean but smooth profile ch...
#
#                                designation  points  price    province  variety
# 132                           Cooper Ranch      90   26.0  California  Barbera
# ...

# %% [markdown]
# This is all the datapoints present in the Barbera dataset

# %%
text38 = " ".join(description for description in df38.description)
print ("The number of words are {}  in the description of Barbera.".format(len(text38)))
# Out:
# The number of words are 326200  in the description of Barbera.

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text38)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df39 = pd.read_csv("/content/Bastardo.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the  Bastardo dataset is used to induct the Bastardo wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df39
# Out:
#          country                                        description  \
# 9083    Portugal  This wine is made from the Bastardo grape whic...
# 13360   Portugal  A very light-colored wine, almost rosé, typica...
# 36501   Portugal  This wine is made from the Bastardo grape whic...
# 49930   Portugal  A very light-colored wine, almost rosé, typica...
# 87861   Portugal  The Bastardo grape is rare in the Douro, but i...
# 104980  Portugal  A very light-colored wine, almost rosé, typica...
# 135591  Portugal  The Bastardo grape is rare in the Douro, but i...
#
#               designation  points  price  province   variety
# 9083                  NaN      86     32     Douro  Bastardo
# 13360   Conceito Bastardo      84     30  Duriense  Bastardo
# 36501                 NaN      86     32     Douro  Bastardo
# 49930   Conceito Bastardo      84     30  Duriense  Bastardo
# 87861   Conceito Bastardo      85     30  Duriense  Bastardo
# ...

# %% [markdown]
# This is all the datapoints present in the Bastardo dataset

# %%
text39 = " ".join(description for description in df39.description)
print ("The number of words are {}  in the description of Bastardo.".format(len(text39)))
# Out:
# The number of words are 1414  in the description of Bastardo.

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text39)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words

# %%
df40 = pd.read_csv("/content/aleatico.csv", index_col=0)

# %% [markdown]
# This statement is used in reading the dataset to the dataframe through the pandas function in python.
#
# Over here the  Aleatico dataset is used to induct the Aleatico wine dataset and it's subsequent data points
#
# if index_col is 0, in this case it means that "1" will be the index of the first column, "2" will be the index for the second column and so on.

# %%
df40
# Out:
#        country                                        description  \
# 12064    Italy  Here's an exciting dessert wine that opens wit...
# 22715    Italy  Pomele is a sweet red wine made from the Aleat...
# 24063    Italy  Nanerone opens with an inky, black color and j...
# 30094    Italy  Here's an exciting dessert wine that opens wit...
# 40893    Italy  Nanerone opens with an inky, black color and j...
# 62840       US  Very sweet but clumsy, with a weird medicinal,...
# 101569   Italy  This Aleatico made from sun-dried grapes is a ...
# 111125   Italy  Not many U.S. wine drinkers will be familiar w...
# 117230      US  Very sweet but clumsy, with a weird medicinal,...
# 118893   Italy  Nanerone opens with an inky, black color and j...
# 140315   Italy  Not many U.S. wine drinkers will be familiar w...
#
#                       designation  points  price       province   variety
# 12064                         NaN      92   50.0  Central Italy  Aleatico
# ...

# %% [markdown]
# This is all the datapoints present in the Aleatico dataset

# %%
text40 = " ".join(description for description in df40.description)
print ("The number of words are {}  in the description of Aleatico.".format(len(text40)))
# Out:
# The number of words are 2779  in the description of Aleatico.

# %% [markdown]
# We are initializing text to join all items in a into a string in from the description column in the current dataset.
# So, in total we are printing all the words present in the description of the dataset under consideration

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords, background_color="white",max_font_size=100, max_words=5).generate(text40)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=[20,10])
plt.show()

# %% [markdown]
# This step is used in separating the stop words (a, an, the) from the total number of words from the description and display the top 5 commonly or most occurring words in the set of total words in the description.
# The highest frequency word will be of the highest size, while the next most occurring word will be the next in size and so on and so forth, while the smallest word in the picture will represent the fifth most occurring word in the total set of description words
